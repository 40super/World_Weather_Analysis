# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config1 import weather_api_key
import time
from datetime import datetime

# %%
#Open weather api 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Generate 2000 long and lats
lats = np.random.uniform(low = -90.000, high=90.000, size=2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 769

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | esil
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | jalalabad
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | huarmey
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | shelburne
# Processing Record 16 of Set 1 | milagro
# Processing Record 17 of Set 1 | maarianhamina
# Processing Record 18 of Set 1 | sao filipe
# Processing Record 19 of Set 1 | tarko-sale
# Processing Record 20 of Set 1 | zaysan
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | lardos
# Processing Record 24 of Set 1 | kasane
# Processing Record 25 of Set 1 | adrar
# Processing Record 26 of Set 1 | vanavara
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | san cristobal
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | ballina
# Processing Record 31 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 1 | tura
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 35 of Set 1 | metkovic
# Processing Record 36 of Set 1 | ust-barguzin
# Processing Record 37 of Set 1 | talaya
# Processing Record 38 of Set 1 | broome
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | ust-maya
# Processing Record 41 of Set 1 | martapura
# Processing Record 42 of Set 1 | rio grande
# Processing Record 43 of Set 1 | kudahuvadhoo
# Processing Record 44 of Set 1 | reshetylivka
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | pimentel
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | kibala
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | filingue
# Processing Record 3 of Set 2 | burica
# City not found. Skipping...
# Processing Record 4 of Set 2 | mahina
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | cap-aux-meules
# Processing Record 7 of Set 2 | pevek
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | aklavik
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | grand gaube
# Processing Record 14 of Set 2 | namibe
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | empalme
# Processing Record 19 of Set 2 | zyryanka
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | oranjestad
# Processing Record 24 of Set 2 | pinsk
# Processing Record 25 of Set 2 | lemesos
# City not found. Skipping...
# Processing Record 26 of Set 2 | micomeseng
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | amantea
# Processing Record 29 of Set 2 | privas
# Processing Record 30 of Set 2 | manvi
# Processing Record 31 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 2 | elko
# Processing Record 33 of Set 2 | kununurra
# Processing Record 34 of Set 2 | colares
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | vidim
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | talnakh
# Processing Record 39 of Set 2 | fethiye
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | poum
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | grand-santi
# Processing Record 45 of Set 2 | catarman
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | okha
# Processing Record 48 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 2 | noumea
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | meulaboh
# Processing Record 2 of Set 3 | san policarpo
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | havre-saint-pierre
# Processing Record 5 of Set 3 | abu samrah
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | nsanje
# Processing Record 8 of Set 3 | novyy urengoy
# Processing Record 9 of Set 3 | nome
# Processing Record 10 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | kuala terengganu
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | mudigere
# Processing Record 17 of Set 3 | wyndham
# Processing Record 18 of Set 3 | hue
# Processing Record 19 of Set 3 | bud
# Processing Record 20 of Set 3 | mecca
# Processing Record 21 of Set 3 | tiznit
# Processing Record 22 of Set 3 | spassk
# Processing Record 23 of Set 3 | ketchikan
# Processing Record 24 of Set 3 | san quintin
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | necochea
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | antofagasta
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 34 of Set 3 | ugoofaaru
# Processing Record 35 of Set 3 | nishihara
# Processing Record 36 of Set 3 | naryan-mar
# Processing Record 37 of Set 3 | sao mateus do sul
# Processing Record 38 of Set 3 | kalemie
# Processing Record 39 of Set 3 | chicama
# Processing Record 40 of Set 3 | zheleznodorozhnyy
# Processing Record 41 of Set 3 | kramat
# Processing Record 42 of Set 3 | avdiyivka
# Processing Record 43 of Set 3 | santa barbara
# Processing Record 44 of Set 3 | karaton
# Processing Record 45 of Set 3 | sorland
# Processing Record 46 of Set 3 | xining
# Processing Record 47 of Set 3 | port macquarie
# Processing Record 48 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 3 | camana
# Processing Record 50 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 4 | bauchi
# Processing Record 2 of Set 4 | husavik
# Processing Record 3 of Set 4 | tokur
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | sibolga
# Processing Record 9 of Set 4 | benguela
# Processing Record 10 of Set 4 | san jeronimo
# Processing Record 11 of Set 4 | huazolotitlan
# City not found. Skipping...
# Processing Record 12 of Set 4 | port lincoln
# Processing Record 13 of Set 4 | portland
# Processing Record 14 of Set 4 | mayumba
# Processing Record 15 of Set 4 | seoul
# Processing Record 16 of Set 4 | quelimane
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | sinnamary
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | port elizabeth
# Processing Record 21 of Set 4 | kiknur
# Processing Record 22 of Set 4 | victoria point
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | la asuncion
# Processing Record 25 of Set 4 | gemona
# Processing Record 26 of Set 4 | aswan
# Processing Record 27 of Set 4 | masakin
# Processing Record 28 of Set 4 | faanui
# Processing Record 29 of Set 4 | fort nelson
# Processing Record 30 of Set 4 | egvekinot
# Processing Record 31 of Set 4 | tautira
# Processing Record 32 of Set 4 | sitka
# Processing Record 33 of Set 4 | cape town
# Processing Record 34 of Set 4 | acapulco
# Processing Record 35 of Set 4 | vardo
# Processing Record 36 of Set 4 | hobyo
# Processing Record 37 of Set 4 | svarstad
# Processing Record 38 of Set 4 | dzierzoniow
# Processing Record 39 of Set 4 | port hardy
# Processing Record 40 of Set 4 | lima
# Processing Record 41 of Set 4 | puerto escondido
# Processing Record 42 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | ahipara
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | ankazobe
# Processing Record 47 of Set 4 | rocha
# Processing Record 48 of Set 4 | carnarvon
# Processing Record 49 of Set 4 | waingapu
# Processing Record 50 of Set 4 | araguacu
# Processing Record 1 of Set 5 | glinka
# Processing Record 2 of Set 5 | mawlaik
# Processing Record 3 of Set 5 | urbana
# Processing Record 4 of Set 5 | wisconsin rapids
# Processing Record 5 of Set 5 | vila velha
# Processing Record 6 of Set 5 | nara
# Processing Record 7 of Set 5 | aleksandrov gay
# Processing Record 8 of Set 5 | mogadishu
# Processing Record 9 of Set 5 | college
# Processing Record 10 of Set 5 | zell am see
# Processing Record 11 of Set 5 | cherskiy
# Processing Record 12 of Set 5 | sena madureira
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | nouadhibou
# Processing Record 15 of Set 5 | san luis
# Processing Record 16 of Set 5 | altamont
# Processing Record 17 of Set 5 | arroyos y esteros
# Processing Record 18 of Set 5 | ust-omchug
# Processing Record 19 of Set 5 | bengkulu
# Processing Record 20 of Set 5 | machaneng
# Processing Record 21 of Set 5 | colac
# Processing Record 22 of Set 5 | lavrentiya
# Processing Record 23 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 5 | tual
# Processing Record 25 of Set 5 | mar del plata
# Processing Record 26 of Set 5 | carlyle
# Processing Record 27 of Set 5 | zatoka
# Processing Record 28 of Set 5 | el real de santa maria
# Processing Record 29 of Set 5 | banda aceh
# Processing Record 30 of Set 5 | payson
# Processing Record 31 of Set 5 | georgetown
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | halifax
# Processing Record 34 of Set 5 | vila
# Processing Record 35 of Set 5 | luderitz
# Processing Record 36 of Set 5 | cusuna
# Processing Record 37 of Set 5 | komsomolskiy
# Processing Record 38 of Set 5 | kaitangata
# Processing Record 39 of Set 5 | nanlong
# Processing Record 40 of Set 5 | baykit
# Processing Record 41 of Set 5 | tucuman
# Processing Record 42 of Set 5 | iqaluit
# Processing Record 43 of Set 5 | ardakan
# Processing Record 44 of Set 5 | shakawe
# Processing Record 45 of Set 5 | pompeu
# Processing Record 46 of Set 5 | parsons
# Processing Record 47 of Set 5 | palafrugell
# Processing Record 48 of Set 5 | marzuq
# Processing Record 49 of Set 5 | san isidro
# Processing Record 50 of Set 5 | lompoc
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | la ronge
# Processing Record 3 of Set 6 | melfort
# Processing Record 4 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 6 | lebu
# Processing Record 6 of Set 6 | lorengau
# Processing Record 7 of Set 6 | salalah
# Processing Record 8 of Set 6 | fortuna
# Processing Record 9 of Set 6 | victoria
# Processing Record 10 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | russell
# Processing Record 13 of Set 6 | beringovskiy
# Processing Record 14 of Set 6 | saint-malo
# Processing Record 15 of Set 6 | shima
# Processing Record 16 of Set 6 | morant bay
# Processing Record 17 of Set 6 | xuddur
# Processing Record 18 of Set 6 | saint anthony
# Processing Record 19 of Set 6 | avera
# Processing Record 20 of Set 6 | morondava
# Processing Record 21 of Set 6 | samoded
# Processing Record 22 of Set 6 | primorsk
# Processing Record 23 of Set 6 | bagdarin
# Processing Record 24 of Set 6 | carora
# Processing Record 25 of Set 6 | lazaro cardenas
# Processing Record 26 of Set 6 | ostrovnoy
# Processing Record 27 of Set 6 | grajewo
# Processing Record 28 of Set 6 | ussel
# Processing Record 29 of Set 6 | gus-zheleznyy
# Processing Record 30 of Set 6 | klaksvik
# Processing Record 31 of Set 6 | carutapera
# Processing Record 32 of Set 6 | pandan niog
# Processing Record 33 of Set 6 | marsa matruh
# Processing Record 34 of Set 6 | padang
# Processing Record 35 of Set 6 | leningradskiy
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | kendari
# Processing Record 38 of Set 6 | marawi
# Processing Record 39 of Set 6 | ushtobe
# Processing Record 40 of Set 6 | vanimo
# Processing Record 41 of Set 6 | evensk
# Processing Record 42 of Set 6 | saint-francois
# Processing Record 43 of Set 6 | antequera
# Processing Record 44 of Set 6 | batagay-alyta
# Processing Record 45 of Set 6 | dunedin
# Processing Record 46 of Set 6 | saint-joseph
# Processing Record 47 of Set 6 | san patricio
# Processing Record 48 of Set 6 | teya
# Processing Record 49 of Set 6 | quatre cocos
# Processing Record 50 of Set 6 | biloela
# Processing Record 1 of Set 7 | champerico
# Processing Record 2 of Set 7 | dakar
# Processing Record 3 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 7 | road town
# Processing Record 5 of Set 7 | guerrero negro
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | los llanos de aridane
# Processing Record 8 of Set 7 | tokzar
# City not found. Skipping...
# Processing Record 9 of Set 7 | lagos
# Processing Record 10 of Set 7 | the valley
# Processing Record 11 of Set 7 | turayf
# Processing Record 12 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 7 | sur
# Processing Record 14 of Set 7 | bilibino
# Processing Record 15 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 7 | ambalavao
# Processing Record 17 of Set 7 | iwanai
# Processing Record 18 of Set 7 | leeton
# Processing Record 19 of Set 7 | iracoubo
# Processing Record 20 of Set 7 | harnai
# Processing Record 21 of Set 7 | wonthaggi
# Processing Record 22 of Set 7 | alice springs
# Processing Record 23 of Set 7 | bosaso
# Processing Record 24 of Set 7 | chippewa falls
# Processing Record 25 of Set 7 | port blair
# Processing Record 26 of Set 7 | margate
# Processing Record 27 of Set 7 | ialibu
# Processing Record 28 of Set 7 | ulladulla
# Processing Record 29 of Set 7 | zonguldak
# Processing Record 30 of Set 7 | roald
# Processing Record 31 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 7 | hermiston
# Processing Record 33 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 7 | yulara
# Processing Record 35 of Set 7 | richards bay
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | pisco
# Processing Record 38 of Set 7 | tuatapere
# Processing Record 39 of Set 7 | christchurch
# Processing Record 40 of Set 7 | pundaguitan
# Processing Record 41 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 7 | mazyr
# Processing Record 43 of Set 7 | tel aviv-yafo
# Processing Record 44 of Set 7 | te anau
# Processing Record 45 of Set 7 | sabratah
# Processing Record 46 of Set 7 | douglas
# Processing Record 47 of Set 7 | moyale
# Processing Record 48 of Set 7 | saint-pierre
# Processing Record 49 of Set 7 | le mans
# Processing Record 50 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 8 | bara
# Processing Record 2 of Set 8 | tuy hoa
# Processing Record 3 of Set 8 | santiago de cao
# Processing Record 4 of Set 8 | bom jesus dos perdoes
# Processing Record 5 of Set 8 | meadow lake
# Processing Record 6 of Set 8 | novichikha
# Processing Record 7 of Set 8 | vestmannaeyjar
# Processing Record 8 of Set 8 | bulgan
# Processing Record 9 of Set 8 | ermelo
# Processing Record 10 of Set 8 | gerash
# Processing Record 11 of Set 8 | miyang
# Processing Record 12 of Set 8 | cassilandia
# Processing Record 13 of Set 8 | murud
# Processing Record 14 of Set 8 | villa carlos paz
# Processing Record 15 of Set 8 | linjiang
# Processing Record 16 of Set 8 | igunga
# Processing Record 17 of Set 8 | labuhan
# Processing Record 18 of Set 8 | sabang
# Processing Record 19 of Set 8 | chepareria
# Processing Record 20 of Set 8 | monterey
# Processing Record 21 of Set 8 | calvinia
# Processing Record 22 of Set 8 | coulommiers
# Processing Record 23 of Set 8 | doha
# Processing Record 24 of Set 8 | byron bay
# Processing Record 25 of Set 8 | teahupoo
# Processing Record 26 of Set 8 | oksfjord
# Processing Record 27 of Set 8 | matay
# Processing Record 28 of Set 8 | dvinskoy
# Processing Record 29 of Set 8 | yangjiang
# Processing Record 30 of Set 8 | axim
# Processing Record 31 of Set 8 | ixtapa
# Processing Record 32 of Set 8 | mackay
# Processing Record 33 of Set 8 | selenginsk
# Processing Record 34 of Set 8 | kawalu
# Processing Record 35 of Set 8 | praia
# Processing Record 36 of Set 8 | pangnirtung
# Processing Record 37 of Set 8 | mahudha
# Processing Record 38 of Set 8 | phan thiet
# Processing Record 39 of Set 8 | santa marta
# Processing Record 40 of Set 8 | chato
# Processing Record 41 of Set 8 | kaniama
# Processing Record 42 of Set 8 | rundu
# Processing Record 43 of Set 8 | verkhoyansk
# Processing Record 44 of Set 8 | turukhansk
# Processing Record 45 of Set 8 | lahij
# Processing Record 46 of Set 8 | bambous virieux
# Processing Record 47 of Set 8 | vysokogornyy
# Processing Record 48 of Set 8 | mahajanga
# Processing Record 49 of Set 8 | santa maria
# Processing Record 50 of Set 8 | tukrah
# Processing Record 1 of Set 9 | jacareacanga
# Processing Record 2 of Set 9 | luziania
# Processing Record 3 of Set 9 | wilmington
# Processing Record 4 of Set 9 | nyimba
# Processing Record 5 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 9 | qaqortoq
# Processing Record 7 of Set 9 | hofn
# Processing Record 8 of Set 9 | comodoro rivadavia
# Processing Record 9 of Set 9 | anadyr
# Processing Record 10 of Set 9 | antalaha
# Processing Record 11 of Set 9 | kamenka
# Processing Record 12 of Set 9 | boden
# Processing Record 13 of Set 9 | northam
# Processing Record 14 of Set 9 | guatire
# Processing Record 15 of Set 9 | port hedland
# Processing Record 16 of Set 9 | gat
# Processing Record 17 of Set 9 | shimoda
# Processing Record 18 of Set 9 | dickinson
# Processing Record 19 of Set 9 | pokhara
# Processing Record 20 of Set 9 | puerto pinasco
# City not found. Skipping...
# Processing Record 21 of Set 9 | san juan evangelista
# Processing Record 22 of Set 9 | kruisfontein
# Processing Record 23 of Set 9 | sakhnovshchyna
# Processing Record 24 of Set 9 | yatou
# Processing Record 25 of Set 9 | hambantota
# Processing Record 26 of Set 9 | alugan
# Processing Record 27 of Set 9 | mindelo
# Processing Record 28 of Set 9 | williams lake
# Processing Record 29 of Set 9 | chinna salem
# Processing Record 30 of Set 9 | asmara
# Processing Record 31 of Set 9 | miles city
# Processing Record 32 of Set 9 | ignacio zaragoza
# Processing Record 33 of Set 9 | arbuzynka
# Processing Record 34 of Set 9 | garden city
# Processing Record 35 of Set 9 | warrnambool
# Processing Record 36 of Set 9 | ogdensburg
# Processing Record 37 of Set 9 | nalagarh
# Processing Record 38 of Set 9 | kukes
# Processing Record 39 of Set 9 | uvalde
# Processing Record 40 of Set 9 | cacador
# Processing Record 41 of Set 9 | srednekolymsk
# Processing Record 42 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 43 of Set 9 | vao
# Processing Record 44 of Set 9 | kachiry
# Processing Record 45 of Set 9 | ocho rios
# Processing Record 46 of Set 9 | vilhena
# Processing Record 47 of Set 9 | sehithwa
# Processing Record 48 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 49 of Set 9 | labuan
# Processing Record 50 of Set 9 | ngunguru
# Processing Record 1 of Set 10 | ossora
# Processing Record 2 of Set 10 | biltine
# Processing Record 3 of Set 10 | panguna
# Processing Record 4 of Set 10 | cardston
# Processing Record 5 of Set 10 | nizhniy kuranakh
# Processing Record 6 of Set 10 | maxixe
# Processing Record 7 of Set 10 | pitimbu
# Processing Record 8 of Set 10 | mayo
# Processing Record 9 of Set 10 | oranjemund
# Processing Record 10 of Set 10 | ridgecrest
# Processing Record 11 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 10 | cozumel
# Processing Record 13 of Set 10 | merauke
# Processing Record 14 of Set 10 | fairbanks
# Processing Record 15 of Set 10 | lac du bonnet
# Processing Record 16 of Set 10 | niamey
# Processing Record 17 of Set 10 | kichera
# Processing Record 18 of Set 10 | palana
# Processing Record 19 of Set 10 | eirunepe
# Processing Record 20 of Set 10 | shakhtne
# Processing Record 21 of Set 10 | asahikawa
# Processing Record 22 of Set 10 | nemuro
# Processing Record 23 of Set 10 | morro bay
# Processing Record 24 of Set 10 | mumford
# Processing Record 25 of Set 10 | sabha
# Processing Record 26 of Set 10 | bathsheba
# Processing Record 27 of Set 10 | rosetta
# Processing Record 28 of Set 10 | ostersund
# Processing Record 29 of Set 10 | mikkeli
# Processing Record 30 of Set 10 | naze
# Processing Record 31 of Set 10 | bubaque
# Processing Record 32 of Set 10 | handan
# Processing Record 33 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 10 | tiarei
# Processing Record 35 of Set 10 | jardim
# Processing Record 36 of Set 10 | ouagadougou
# Processing Record 37 of Set 10 | ende
# Processing Record 38 of Set 10 | ambulu
# Processing Record 39 of Set 10 | kautokeino
# Processing Record 40 of Set 10 | el alto
# Processing Record 41 of Set 10 | mareeba
# Processing Record 42 of Set 10 | kayerkan
# Processing Record 43 of Set 10 | paamiut
# Processing Record 44 of Set 10 | yerbogachen
# Processing Record 45 of Set 10 | puerto padre
# Processing Record 46 of Set 10 | zambezi
# Processing Record 47 of Set 10 | kondinskoye
# Processing Record 48 of Set 10 | jacqueville
# Processing Record 49 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 10 | sakakah
# Processing Record 1 of Set 11 | bilma
# Processing Record 2 of Set 11 | bell ville
# Processing Record 3 of Set 11 | wagar
# Processing Record 4 of Set 11 | asau
# Processing Record 5 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 6 of Set 11 | sumiswald
# Processing Record 7 of Set 11 | pontianak
# Processing Record 8 of Set 11 | puerto leguizamo
# Processing Record 9 of Set 11 | zelenoborskiy
# Processing Record 10 of Set 11 | bhatapara
# Processing Record 11 of Set 11 | preobrazheniye
# Processing Record 12 of Set 11 | carhuamayo
# Processing Record 13 of Set 11 | yelizavetino
# Processing Record 14 of Set 11 | elyria
# Processing Record 15 of Set 11 | priiskovyy
# Processing Record 16 of Set 11 | falmouth
# Processing Record 17 of Set 11 | kyshtovka
# Processing Record 18 of Set 11 | qasigiannguit
# Processing Record 19 of Set 11 | eureka
# Processing Record 20 of Set 11 | hualmay
# Processing Record 21 of Set 11 | soe
# Processing Record 22 of Set 11 | moscavide
# Processing Record 23 of Set 11 | hirara
# Processing Record 24 of Set 11 | senno
# Processing Record 25 of Set 11 | san pedro
# Processing Record 26 of Set 11 | rehoboth
# Processing Record 27 of Set 11 | gornozavodsk
# Processing Record 28 of Set 11 | thinadhoo
# Processing Record 29 of Set 11 | batagay
# Processing Record 30 of Set 11 | vieste
# Processing Record 31 of Set 11 | oktyabrskoye
# Processing Record 32 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 11 | itanhem
# Processing Record 34 of Set 11 | port augusta
# Processing Record 35 of Set 11 | yar-sale
# Processing Record 36 of Set 11 | belousovka
# Processing Record 37 of Set 11 | savannah bight
# Processing Record 38 of Set 11 | sioux lookout
# Processing Record 39 of Set 11 | elat
# Processing Record 40 of Set 11 | bahar
# Processing Record 41 of Set 11 | coihaique
# Processing Record 42 of Set 11 | saint-augustin
# Processing Record 43 of Set 11 | chuy
# Processing Record 44 of Set 11 | sar-e pul
# Processing Record 45 of Set 11 | motala
# Processing Record 46 of Set 11 | roros
# Processing Record 47 of Set 11 | caravelas
# Processing Record 48 of Set 11 | dingle
# Processing Record 49 of Set 11 | kadoma
# Processing Record 50 of Set 11 | lixourion
# Processing Record 1 of Set 12 | ca mau
# Processing Record 2 of Set 12 | novorudnyy
# Processing Record 3 of Set 12 | jiazi
# Processing Record 4 of Set 12 | pokaran
# Processing Record 5 of Set 12 | shaunavon
# Processing Record 6 of Set 12 | kuytun
# Processing Record 7 of Set 12 | kaeo
# Processing Record 8 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 12 | tambovka
# Processing Record 10 of Set 12 | dalbandin
# Processing Record 11 of Set 12 | biak
# Processing Record 12 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 12 | mana
# Processing Record 14 of Set 12 | jequitinhonha
# Processing Record 15 of Set 12 | venado tuerto
# Processing Record 16 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 12 | frontera
# Processing Record 18 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 12 | flin flon
# Processing Record 20 of Set 12 | basco
# Processing Record 21 of Set 12 | jampur
# Processing Record 22 of Set 12 | puerto colombia
# Processing Record 23 of Set 12 | strezhevoy
# Processing Record 24 of Set 12 | ormara
# Processing Record 25 of Set 12 | luwingu
# Processing Record 26 of Set 12 | okhotsk
# Processing Record 27 of Set 12 | korla
# Processing Record 28 of Set 12 | oum hadjer
# Processing Record 29 of Set 12 | atherton
# Processing Record 30 of Set 12 | soria
# Processing Record 31 of Set 12 | vila franca do campo
# Processing Record 32 of Set 12 | hamilton
# Processing Record 33 of Set 12 | townsville
# Processing Record 34 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 12 | muzaffarpur
# Processing Record 36 of Set 12 | garowe
# Processing Record 37 of Set 12 | penzance
# Processing Record 38 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | estelle
# Processing Record 40 of Set 12 | moose factory
# Processing Record 41 of Set 12 | gigmoto
# Processing Record 42 of Set 12 | codrington
# Processing Record 43 of Set 12 | namatanai
# Processing Record 44 of Set 12 | oudtshoorn
# Processing Record 45 of Set 12 | santa maria del oro
# Processing Record 46 of Set 12 | aksarka
# Processing Record 47 of Set 12 | haimen
# Processing Record 48 of Set 12 | kroya
# Processing Record 49 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 12 | luanda
# Processing Record 1 of Set 13 | kijang
# Processing Record 2 of Set 13 | nzega
# Processing Record 3 of Set 13 | mahon
# Processing Record 4 of Set 13 | sezana
# Processing Record 5 of Set 13 | nenita
# Processing Record 6 of Set 13 | belyy yar
# Processing Record 7 of Set 13 | airai
# Processing Record 8 of Set 13 | sao joao batista
# Processing Record 9 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 13 | rio gallegos
# Processing Record 11 of Set 13 | ojinaga
# Processing Record 12 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 13 | yumen
# Processing Record 14 of Set 13 | taua
# Processing Record 15 of Set 13 | novosheshminsk
# Processing Record 16 of Set 13 | nyandoma
# Processing Record 17 of Set 13 | valparaiso
# Processing Record 18 of Set 13 | visnes
# Processing Record 19 of Set 13 | whitehorse
# Processing Record 20 of Set 13 | kingaroy
# Processing Record 21 of Set 13 | pribinic
# Processing Record 22 of Set 13 | lagoa
# Processing Record 23 of Set 13 | drabiv
# Processing Record 24 of Set 13 | mantua
# Processing Record 25 of Set 13 | pingliang
# Processing Record 26 of Set 13 | constitucion
# Processing Record 27 of Set 13 | saint pete beach
# Processing Record 28 of Set 13 | gold coast
# Processing Record 29 of Set 13 | lam luk ka
# Processing Record 30 of Set 13 | kristiinankaupunki
# Processing Record 31 of Set 13 | mount barker
# Processing Record 32 of Set 13 | terney
# Processing Record 33 of Set 13 | sisimiut
# Processing Record 34 of Set 13 | latung
# Processing Record 35 of Set 13 | scottsbluff
# Processing Record 36 of Set 13 | puerto rico
# Processing Record 37 of Set 13 | griffith
# Processing Record 38 of Set 13 | kaberamaido
# Processing Record 39 of Set 13 | auki
# Processing Record 40 of Set 13 | mondlo
# Processing Record 41 of Set 13 | san juan
# Processing Record 42 of Set 13 | bairiki
# Processing Record 43 of Set 13 | cockburn town
# Processing Record 44 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 13 | susehri
# Processing Record 46 of Set 13 | xam nua
# Processing Record 47 of Set 13 | garoua
# Processing Record 48 of Set 13 | homer
# Processing Record 49 of Set 13 | makakilo city
# Processing Record 50 of Set 13 | libertador general san martin
# Processing Record 1 of Set 14 | aranos
# Processing Record 2 of Set 14 | dudinka
# Processing Record 3 of Set 14 | hami
# Processing Record 4 of Set 14 | lerwick
# Processing Record 5 of Set 14 | rebra
# Processing Record 6 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 14 | umm kaddadah
# Processing Record 8 of Set 14 | winnemucca
# Processing Record 9 of Set 14 | sobolevo
# Processing Record 10 of Set 14 | umea
# Processing Record 11 of Set 14 | praxedis guerrero
# Processing Record 12 of Set 14 | cap malheureux
# Processing Record 13 of Set 14 | baherden
# Processing Record 14 of Set 14 | karaikkudi
# Processing Record 15 of Set 14 | muravlenko
# Processing Record 16 of Set 14 | ivdel
# Processing Record 17 of Set 14 | levelland
# Processing Record 18 of Set 14 | horsham
# Processing Record 19 of Set 14 | jaisalmer
# Processing Record 20 of Set 14 | novoilinsk
# Processing Record 21 of Set 14 | paraopeba
# Processing Record 22 of Set 14 | le vauclin
# Processing Record 23 of Set 14 | massakory
# Processing Record 24 of Set 14 | ust-koksa
# Processing Record 25 of Set 14 | copiapo
# Processing Record 26 of Set 14 | tabou
# Processing Record 27 of Set 14 | wanning
# Processing Record 28 of Set 14 | kiunga
# Processing Record 29 of Set 14 | chabahar
# Processing Record 30 of Set 14 | erenhot
# Processing Record 31 of Set 14 | berlevag
# Processing Record 32 of Set 14 | stephenville
# Processing Record 33 of Set 14 | caraquet
# Processing Record 34 of Set 14 | aquiraz
# Processing Record 35 of Set 14 | grindavik
# Processing Record 36 of Set 14 | pekan
# Processing Record 37 of Set 14 | asosa
# Processing Record 38 of Set 14 | svetlaya
# Processing Record 39 of Set 14 | kelowna
# Processing Record 40 of Set 14 | taltal
# Processing Record 41 of Set 14 | koumac
# Processing Record 42 of Set 14 | uzunovo
# Processing Record 43 of Set 14 | maraa
# Processing Record 44 of Set 14 | san francisco de ojuera
# Processing Record 45 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 14 | sidi ali
# Processing Record 47 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 48 of Set 14 | alyangula
# Processing Record 49 of Set 14 | ulaangom
# Processing Record 50 of Set 14 | nouakchott
# Processing Record 1 of Set 15 | touros
# Processing Record 2 of Set 15 | moerai
# Processing Record 3 of Set 15 | shingu
# Processing Record 4 of Set 15 | trincomalee
# Processing Record 5 of Set 15 | olafsvik
# Processing Record 6 of Set 15 | oron
# Processing Record 7 of Set 15 | koyilandi
# City not found. Skipping...
# Processing Record 8 of Set 15 | half moon bay
# Processing Record 9 of Set 15 | itoman
# Processing Record 10 of Set 15 | osakarovka
# Processing Record 11 of Set 15 | saint-louis
# Processing Record 12 of Set 15 | ribeira brava
# Processing Record 13 of Set 15 | makat
# Processing Record 14 of Set 15 | muncar
# Processing Record 15 of Set 15 | mount pleasant
# Processing Record 16 of Set 15 | pucallpa
# Processing Record 17 of Set 15 | topeka
# Processing Record 18 of Set 15 | newport
# Processing Record 19 of Set 15 | lata
# Processing Record 20 of Set 15 | blagoyevo
# Processing Record 21 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 22 of Set 15 | tretten
# Processing Record 23 of Set 15 | ponta delgada
# Processing Record 24 of Set 15 | njombe
# Processing Record 25 of Set 15 | vadso
# Processing Record 26 of Set 15 | ondangwa
# Processing Record 27 of Set 15 | vulcan
# Processing Record 28 of Set 15 | magadan
# Processing Record 29 of Set 15 | artigas
# Processing Record 30 of Set 15 | high level
# Processing Record 31 of Set 15 | jelenia gora
# Processing Record 32 of Set 15 | mantenopolis
# Processing Record 33 of Set 15 | nabire
# Processing Record 34 of Set 15 | butterworth
# Processing Record 35 of Set 15 | peniche
# Processing Record 36 of Set 15 | sao joao da barra
# Processing Record 37 of Set 15 | key largo
# Processing Record 38 of Set 15 | teguldet
# Processing Record 39 of Set 15 | wenling
# Processing Record 40 of Set 15 | semme
# Processing Record 41 of Set 15 | mombetsu
# Processing Record 42 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 15 | pacific grove
# Processing Record 44 of Set 15 | luzhou
# Processing Record 45 of Set 15 | coquimbo
# Processing Record 46 of Set 15 | bageshwar
# Processing Record 47 of Set 15 | alofi
# Processing Record 48 of Set 15 | marathopolis
# City not found. Skipping...
# Processing Record 49 of Set 15 | barra do corda
# Processing Record 50 of Set 15 | ambon
# Processing Record 1 of Set 16 | finschhafen
# Processing Record 2 of Set 16 | atar
# Processing Record 3 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 16 | dhidhdhoo
# Processing Record 5 of Set 16 | hendijan
# City not found. Skipping...
# Processing Record 6 of Set 16 | soyo
# Processing Record 7 of Set 16 | kargasok
# Processing Record 8 of Set 16 | cidreira
# Processing Record 9 of Set 16 | monte cristi
# City not found. Skipping...
# Processing Record 10 of Set 16 | montana
# Processing Record 11 of Set 16 | ullapool
# Processing Record 12 of Set 16 | skelleftea
# Processing Record 13 of Set 16 | gamba
# Processing Record 14 of Set 16 | nioro
# Processing Record 15 of Set 16 | tokuyama
# Processing Record 16 of Set 16 | bemidji
# Processing Record 17 of Set 16 | kissidougou
# Processing Record 18 of Set 16 | kanye
# Processing Record 19 of Set 16 | taoudenni
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 714

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
new_col_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_col_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     47.34        85          21
# 1          Esil      KZ  51.9556   66.4042     66.45        36           5
# 2   Provideniya      RU  64.3833 -173.3000     46.36       100         100
# 3     Jalalabad      AF  34.4265   70.4515     84.38        49           0
# 4        Albany      US  42.6001  -73.9662     92.03        54          28
# 5   Tuktoyaktuk      CA  69.4541 -133.0374     44.60        93         100
# 6        Avarua      CK -21.2078 -159.7750     77.05        78          82
# 7       Huarmey      PE -10.0681  -78.1522     67.30        71          12
# 8  Saint George      US  37.1041 -113.5841    101.79        20           0
# 9       Mataura      NZ -46.1927  168.8643     41.49        79          49
#
#    Wind Speed      Current Description
# 0        6.33               few clouds
# 1        6.17                clear sky
# 2        1.99          overcast clouds
# 3        2.84                clear sky
# 4        4.00         scattered clouds
# 5        2.30  light intensity drizzle
# 6        5.75            broken clouds
# 7       11.68               few clouds
# 8        1.99                clear sky
# 9        2.48         scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
